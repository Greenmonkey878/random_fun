# %%
import pandas as pd

# %%
stargate_sg1 = pd.read_html('https://en.wikipedia.org/wiki/Stargate_SG-1')

# %%
len(stargate_sg1)
# Out:
# 16

# %%
stargate_sg1[1]
# Out:
#           Character           Portrayed by Seasons                           \
#           Character           Portrayed by       1     2     3     4      5
# 0      Jack O'Neill  Richard Dean Anderson    Main  Main  Main  Main   Main
# 1    Daniel Jackson         Michael Shanks    Main  Main  Main  Main   Main
# 2   Samantha Carter         Amanda Tapping    Main  Main  Main  Main   Main
# 3            Teal'c      Christopher Judge    Main  Main  Main  Main   Main
# 4    George Hammond           Don S. Davis    Main  Main  Main  Main   Main
# 5       Jonas Quinn            Corin Nemec     NaN   NaN   NaN   NaN  Guest
# 6  Cameron Mitchell            Ben Browder     NaN   NaN   NaN   NaN    NaN
# 7       Hank Landry           Beau Bridges     NaN   NaN   NaN   NaN    NaN
# 8    Vala Mal Doran          Claudia Black     NaN   NaN   NaN   NaN    NaN
#
#                                                                Movies  \
# ...
